# %% [markdown]
# # ENEM 2016 Classification

# %% [markdown]
# ## Importings

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)

import matplotlib as plt
import seaborn as sns

# sns.set()

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

train.shape, test.shape
# Out:
# ((13730, 167), (4570, 43))

# %% [markdown]
# ## Visualization

# %%
train.head(3)
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# 2                  2304400               Fortaleza                23
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0               RS        24       M              0.0            1
# 1               CE        17       F              0.0            3
# 2               CE        21       F              0.0            3
#
#    TP_NACIONALIDADE  CO_MUNICIPIO_NASCIMENTO NO_MUNICIPIO_NASCIMENTO  \
# 0                 1                4314902.0            Porto Alegre
# ...

# %%
test.head(3)
# Out:
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               RS        19       F            1                 1
# 1               PA        24       M            3                 2
# 2               BA        16       F            2                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  \
# 0                1                3          1        NaN
# 1                1                4          1        NaN
# 2                3                0          1        NaN
#
#    TP_DEPENDENCIA_ADM_ESC  IN_BAIXA_VISAO  IN_CEGUEIRA  IN_SURDEZ  \
# 0                     NaN               0            0          0
# 1                     NaN               0            0          0
# 2                     NaN               0            0          0
#
#    IN_DISLEXIA  IN_DISCALCULIA  IN_SABATISTA  IN_GESTANTE  IN_IDOSO  \
# 0            0               0             0            0         0
# ...

# %% [markdown]
# Droping columns

# %%
test_inscricao = test.pop("NU_INSCRICAO")

# %%
test.drop(["CO_UF_RESIDENCIA"], axis=1, inplace=True)

# %%
test.head(3)
# Out:
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               RS        19       F            1                 1
# 1               PA        24       M            3                 2
# 2               BA        16       F            2                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  \
# 0                1                3          1        NaN
# 1                1                4          1        NaN
# 2                3                0          1        NaN
#
#    TP_DEPENDENCIA_ADM_ESC  IN_BAIXA_VISAO  IN_CEGUEIRA  IN_SURDEZ  \
# 0                     NaN               0            0          0
# 1                     NaN               0            0          0
# 2                     NaN               0            0          0
#
#    IN_DISLEXIA  IN_DISCALCULIA  IN_SABATISTA  IN_GESTANTE  IN_IDOSO  \
# 0            0               0             0            0         0
# ...

# %% [markdown]
# Defining the target and counting the distribution

# %%
target = train["IN_TREINEIRO"]
sns.countplot(target);

# %%
test.isna().sum()
# Out:
# SG_UF_RESIDENCIA          0
# NU_IDADE                  0
# TP_SEXO                   0
# TP_COR_RACA               0
# TP_NACIONALIDADE          0
# TP_ST_CONCLUSAO           0
# TP_ANO_CONCLUIU           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# TP_DEPENDENCIA_ADM_ESC    0
# IN_BAIXA_VISAO            0
# IN_CEGUEIRA               0
# IN_SURDEZ                 0
# IN_DISLEXIA               0
# IN_DISCALCULIA            0
# IN_SABATISTA              0
# IN_GESTANTE               0
# IN_IDOSO                  0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# TP_PRESENCA_MT            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# TP_LINGUA                 0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# NU_NOTA_REDACAO           0
# ...

# %%
print(train["TP_ENSINO"].median(), train["TP_DEPENDENCIA_ADM_ESC"].median(), train["Q027"].mode()[0])
print(test["TP_ENSINO"].median(), test["TP_DEPENDENCIA_ADM_ESC"].median(), test["Q027"].mode()[0])
# Out:
# 1.0 2.0 F
# 1.0 2.0 F

# %%
train["TP_ENSINO"].fillna(1, inplace=True)
train["TP_DEPENDENCIA_ADM_ESC"].fillna(2, inplace=True)
train["Q027"].fillna("F", inplace=True)
train.fillna(0, inplace=True)
test["TP_ENSINO"].fillna(1, inplace=True)
test["TP_DEPENDENCIA_ADM_ESC"].fillna(2, inplace=True)
test["Q027"].fillna("F", inplace=True)
test.fillna(0, inplace=True)

# %%
train = train[test.columns]
train.shape, test.shape
# Out:
# ((13730, 41), (4570, 41))

# %%
train = pd.get_dummies(train)
test = pd.get_dummies(test)

train.shape, test.shape
# Out:
# ((13730, 121), (4570, 121))

# %% [markdown]
# ## Training

# %%
xtrain, xtest, ytrain, ytest = train_test_split(train, target, train_size=.7, random_state=42)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((9611, 121), (4119, 121), (9611,), (4119,))

# %%
mdl = DecisionTreeClassifier(max_depth=3,random_state=42)
mdl.fit(xtrain, ytrain)
p = mdl.predict(xtest)

# %%
print(classification_report(ytest, p, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9964    1.0000    0.9982      3577
#            1     1.0000    0.9760    0.9879       542
#
#     accuracy                         0.9968      4119
#    macro avg     0.9982    0.9880    0.9930      4119
# weighted avg     0.9969    0.9968    0.9968      4119

# %%
from sklearn.metrics import confusion_matrix, f1_score

confusion_matrix(ytest, p)
# Out:
# array([[3577,    0],
#        [  13,  529]], dtype=int64)

# %%
f1_score(ytest, p)
# Out:
# 0.9878618113912232

# %%
tree.plot_tree(mdl);

# %%
test_result = mdl.predict(test)
test_result
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
answer = pd.DataFrame(test_result, index=test_inscricao)
answer.columns = ["IN_TREINEIRO"]
answer.to_csv("answer.csv")
